# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib.pyplot
# Out:
# UsageError: Line magic function `%matplotlib.pyplot` not found.

# %%
df = pd.read_csv('train_u6lujuX_CVtuZ9i (1).csv')

# %%
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
sns.countplot(x='Loan_Status',hue='Education',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(x='Loan_Status',hue='Married',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
sns.countplot(x='Self_Employed',hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Self_Employed', ylabel='count'>

# %%
sns.countplot(hue='Self_Employed',x='Loan_Status',data=df)
# Out:
# <AxesSubplot:xlabel='Loan_Status', ylabel='count'>

# %%
df.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
df_1=label.fit_transform(df[['Gender']])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py:115: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df['Gender']=df_1

# %%
df.head(2)
# Out:
#     Loan_ID  Gender Married Dependents Education Self_Employed  \
# 0  LP001002       1      No          0  Graduate            No
# 1  LP001003       1     Yes          1  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N

# %%
df.replace({'Married':{'Yes':1,'No':0}},inplace=True)

# %%
df.head(10)
# Out:
#     Loan_ID  Gender  Married Dependents     Education Self_Employed  \
# 0  LP001002       1      0.0          0      Graduate            No
# 1  LP001003       1      1.0          1      Graduate            No
# 2  LP001005       1      1.0          0      Graduate           Yes
# 3  LP001006       1      1.0          0  Not Graduate            No
# 4  LP001008       1      0.0          0      Graduate            No
# 5  LP001011       1      1.0          2      Graduate           Yes
# 6  LP001013       1      1.0          0  Not Graduate            No
# 7  LP001014       1      1.0         3+      Graduate            No
# 8  LP001018       1      1.0          2      Graduate            No
# 9  LP001020       1      1.0          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df = df.replace(to_replace='3+',value=4)

# %%
df['Dependents'].value_counts()
# Out:
# 0    345
# 1    102
# 2    101
# 4     51
# Name: Dependents, dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.head(10)
# Out:
#      Loan_ID  Gender  Married Dependents     Education Self_Employed  \
# 1   LP001003       1      1.0          1      Graduate            No
# 2   LP001005       1      1.0          0      Graduate           Yes
# 3   LP001006       1      1.0          0  Not Graduate            No
# 4   LP001008       1      0.0          0      Graduate            No
# 5   LP001011       1      1.0          2      Graduate           Yes
# 6   LP001013       1      1.0          0  Not Graduate            No
# 7   LP001014       1      1.0          4      Graduate            No
# 8   LP001018       1      1.0          2      Graduate            No
# 9   LP001020       1      1.0          1      Graduate            No
# 10  LP001024       1      1.0          2      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1              4583             1508.0       128.0             360.0
# ...

# %%
df.replace(to_replace={'Education':{'Graduate':1,
                                   'Not Graduate':0},'Self_Employed':{'No':0,
                                                                     'Yes':1}},inplace=True)

# %%
df['Education'].value_counts()
# Out:
# 1    394
# 0     98
# Name: Education, dtype: int64

# %%
df['Self_Employed'].value_counts()
# Out:
# 0    423
# 1     69
# Name: Self_Employed, dtype: int64

# %%
df.head(10)
# Out:
#      Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1   LP001003       1      1.0          1          1              0
# 2   LP001005       1      1.0          0          1              1
# 3   LP001006       1      1.0          0          0              0
# 4   LP001008       1      0.0          0          1              0
# 5   LP001011       1      1.0          2          1              1
# 6   LP001013       1      1.0          0          0              0
# 7   LP001014       1      1.0          4          1              0
# 8   LP001018       1      1.0          2          1              0
# 9   LP001020       1      1.0          1          1              0
# 10  LP001024       1      1.0          2          1              0
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1              4583             1508.0       128.0             360.0
# 2              3000                0.0        66.0             360.0
# ...

# %%
df_2=label.fit_transform(df['Loan_Status'])

# %%
df['Loan_Status'] = df_2

# %%
df_3=label.fit_transform(df['Property_Area'])

# %%
df['Property_Area']=df_3

# %%
df.head(20)
# Out:
#      Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 1   LP001003       1      1.0          1          1              0
# 2   LP001005       1      1.0          0          1              1
# 3   LP001006       1      1.0          0          0              0
# 4   LP001008       1      0.0          0          1              0
# 5   LP001011       1      1.0          2          1              1
# 6   LP001013       1      1.0          0          0              0
# 7   LP001014       1      1.0          4          1              0
# 8   LP001018       1      1.0          2          1              0
# 9   LP001020       1      1.0          1          1              0
# 10  LP001024       1      1.0          2          1              0
# 12  LP001028       1      1.0          2          1              0
# 13  LP001029       1      0.0          0          1              0
# 14  LP001030       1      1.0          2          1              0
# ...

# %%
df['Property_Area'].value_counts()
# Out:
# 1    349
# 0    143
# Name: Property_Area, dtype: int64

# %%
from sklearn.svm import SVC

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
from sklearn.metrics import accuracy_score

# %%
svm = SVC()

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop(columns=['Loan_ID','Loan_Status'],axis=1)

# %%
X
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 1         1      1.0          1          1              0             4583
# 2         1      1.0          0          1              1             3000
# 3         1      1.0          0          0              0             2583
# 4         1      0.0          0          1              0             6000
# 5         1      1.0          2          1              1             5417
# ..      ...      ...        ...        ...            ...              ...
# 609       0      0.0          0          1              0             2900
# 610       1      1.0          4          1              0             4106
# 611       1      1.0          1          1              0             8072
# 612       1      1.0          2          1              0             7583
# 613       0      0.0          0          1              1             4583
#
# ...

# %%
Y=df['Loan_Status']

# %%
Y
# Out:
# 1      0
# 2      1
# 3      1
# 4      1
# 5      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 492, dtype: int64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=101)

# %%
svm.fit(X_train,Y_train)
# Out:
# SVC()

# %%
pred_train = svm.predict(X_train)

# %%
train_accuracy = accuracy_score(Y_train,pred_train)

# %%
train_accuracy
# Out:
# 0.6844783715012722

# %%
pred_test = svm.predict(X_test)

# %%
test_accuracy = accuracy_score(Y_test,pred_test)

# %%
test_accuracy
# Out:
# 0.7272727272727273

# %%
in_array =(1,1.0,1,1,0,12841,10968.0,349.0,360.0,1.0,1)

# %%
n_ar = np.asarray(in_array).reshape(1,-1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
n_scaler = scaler.fit_transform(n_ar)

# %%
pred_array = svm.predict(n_scaler)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
if pred_array==1:
    print(pred_array)
    print('Loan will be Santioned')
else:
    print(pred_array)
    print('Loan will not be santioned')
# Out:
# [1]
# Loan will be Santioned
